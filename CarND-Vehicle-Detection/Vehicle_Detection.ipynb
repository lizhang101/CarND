# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import utilities as util

# %%
import glob
tests = sorted(glob.glob("./test_images/*.jpg"))
#tests = sorted(glob.glob("./harder_challenge/*.jpg"))
n = len(tests)
test_images = []
w = h = 0
for i, imgf in enumerate(tests):
    img = cv2.imread(imgf)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    w,h = img.shape[1::-1]
    test_images.append(img)

# %%
import importlib
importlib.reload(util)
# Out:
# <module 'utilities' from '/home/lizhang/workspace/Udacity/CarND/CarND-Vehicle-Detection/utilities.py'>

# %%
hist0 = util.ColorHist(test_images[0])
hist0.show()

# %%
hsv0 = util.ColorSpace(test_images[0],'yrb')
hsv0.show()
